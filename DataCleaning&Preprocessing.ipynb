# %% [markdown]
# ## Data Collection

# %% [markdown]
# Importing Pandas Library

# %%
import pandas as pd

# %% [markdown]
# Importing Dataset

# %%
housing = pd.read_csv('/content/property_rent_data.csv')

# %% [markdown]
# Quick View of Data

# %%
housing.head()
# Out:
#    Type  Number of Rooms  Number of Bathrooms  Area (sqft)  \
# 0  Flat                4                    1      922.441
# 1    PG                1                    1      156.777
# 2  Flat                4                    2      994.201
# 3  Flat                3                    2      618.653
# 4  Flat                3                    1      799.278
#
#    Amenities Distance Avg (km)  Parking Spaces  Age (years)     Location  \
# 0                       2.0858               0         22.3        Saket
# 1                      14.2736               0          8.7  Mayur Vihar
# 2                      14.8662               2         14.2  Mayur Vihar
# 3                       8.5457               2         15.6  Vasant Kunj
# 4                       3.1601               1         16.3    New Delhi
#
#    Crime Rate  Lower Status Population  Avg People in Building    Rent Price
# 0        1.29                     0.24                 43.8702  42641.971016
# ...

# %%
# @title Area (sqft)

from matplotlib import pyplot as plt
housing['Area (sqft)'].plot(kind='hist', bins=20, title='Area (sqft)')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# Dataset Info

# %%
housing.info()        #No Null Values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5880 entries, 0 to 5879
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Type                         5880 non-null   object
#  1   Number of Rooms              5880 non-null   int64
#  2   Number of Bathrooms          5880 non-null   int64
#  3   Area (sqft)                  5880 non-null   float64
#  4   Amenities Distance Avg (km)  5880 non-null   float64
#  5   Parking Spaces               5880 non-null   int64
#  6   Age (years)                  5880 non-null   float64
#  7   Location                     5880 non-null   object
#  8   Crime Rate                   5880 non-null   float64
#  9   Lower Status Population      5880 non-null   float64
#  10  Avg People in Building       5880 non-null   float64
#  11  Rent Price                   5880 non-null   float64
# dtypes: float64(7), int64(3), object(2)
# ...

# %% [markdown]
# Showing Value Counts on different Attributes

# %%
housing['Type'].value_counts()
# Out:
# Type
# Flat    4405
# PG      1475
# Name: count, dtype: int64

# %%
housing['Location'].value_counts()
# Out:
# Location
# New Delhi        696
# Mayur Vihar      695
# Faridabad        693
# Gurgaon          652
# Dwarka           648
# Saket            644
# Greater Noida    628
# Noida            622
# Vasant Kunj      602
# Name: count, dtype: int64

# %%
housing['Parking Spaces'].value_counts()
# Out:
# Parking Spaces
# 0    2016
# 1    1945
# 2    1919
# Name: count, dtype: int64

# %% [markdown]
# Dataset Description

# %%
housing.describe()
# Out:
#        Number of Rooms  Number of Bathrooms  Area (sqft)  \
# count      5880.000000          5880.000000  5880.000000
# mean          2.126701             1.560374   437.121144
# std           1.171224             0.864582   282.364317
# min           1.000000             1.000000   100.007000
# 25%           1.000000             1.000000   200.399750
# 50%           2.000000             1.000000   359.116500
# 75%           3.000000             2.000000   614.708000
# max           4.000000             4.000000  1198.946000
#
#        Amenities Distance Avg (km)  Parking Spaces  Age (years)   Crime Rate  \
# count                  5880.000000     5880.000000  5880.000000  5880.000000
# mean                      7.529588        0.983503    12.656769     0.992765
# std                       4.298144        0.817960     7.185015     0.574108
# min                       0.109900        0.000000     0.000000     0.010000
# ...

# %% [markdown]
# ## Data Visualization

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
housing.hist(bins=50, figsize=(20,15), color='red')
# Out:
# array([[<Axes: title={'center': 'Number of Rooms'}>,
#         <Axes: title={'center': 'Number of Bathrooms'}>,
#         <Axes: title={'center': 'Area (sqft)'}>],
#        [<Axes: title={'center': 'Amenities Distance Avg (km)'}>,
#         <Axes: title={'center': 'Parking Spaces'}>,
#         <Axes: title={'center': 'Age (years)'}>],
#        [<Axes: title={'center': 'Crime Rate'}>,
#         <Axes: title={'center': 'Lower Status Population'}>,
#         <Axes: title={'center': 'Avg People in Building'}>],
#        [<Axes: title={'center': 'Rent Price'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
import seaborn as sns
figsize = (12, 1.2 * len(housing['Type'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(housing, x='Area (sqft)', y='Type', inner='box', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)
# Out:
# <ipython-input-10-7f70073069dd>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(housing, x='Area (sqft)', y='Type', inner='box', palette='Dark2')

# %%
from pandas.plotting import scatter_matrix
attributes = ['Rent Price', 'Number of Rooms', 'Area (sqft)','Age (years)']
scatter_matrix(housing[attributes], figsize=(12,8))
# Out:
# array([[<Axes: xlabel='Rent Price', ylabel='Rent Price'>,
#         <Axes: xlabel='Number of Rooms', ylabel='Rent Price'>,
#         <Axes: xlabel='Area (sqft)', ylabel='Rent Price'>,
#         <Axes: xlabel='Age (years)', ylabel='Rent Price'>],
#        [<Axes: xlabel='Rent Price', ylabel='Number of Rooms'>,
#         <Axes: xlabel='Number of Rooms', ylabel='Number of Rooms'>,
#         <Axes: xlabel='Area (sqft)', ylabel='Number of Rooms'>,
#         <Axes: xlabel='Age (years)', ylabel='Number of Rooms'>],
#        [<Axes: xlabel='Rent Price', ylabel='Area (sqft)'>,
#         <Axes: xlabel='Number of Rooms', ylabel='Area (sqft)'>,
#         <Axes: xlabel='Area (sqft)', ylabel='Area (sqft)'>,
#         <Axes: xlabel='Age (years)', ylabel='Area (sqft)'>],
#        [<Axes: xlabel='Rent Price', ylabel='Age (years)'>,
#         <Axes: xlabel='Number of Rooms', ylabel='Age (years)'>,
#         <Axes: xlabel='Area (sqft)', ylabel='Age (years)'>,
# ...

# %%
housing.plot(kind="scatter",x="Rent Price",y="Area (sqft)", alpha=0.15, title="Rent Price vs Area (sqft)")
# Out:
# <Axes: title={'center': 'Rent Price vs Area (sqft)'}, xlabel='Rent Price', ylabel='Area (sqft)'>

# %%
housing.plot(kind="scatter",x="Rent Price",y="Age (years)", alpha=0.15, title="Rent Price vs Age (years)")
# Out:
# <Axes: title={'center': 'Rent Price vs Age (years)'}, xlabel='Rent Price', ylabel='Age (years)'>

# %%
housing.plot(kind="scatter",x="Rent Price",y="Crime Rate", alpha=0.15, title="Rent Price vs Crime Rate")
# Out:
# <Axes: title={'center': 'Rent Price vs Crime Rate'}, xlabel='Rent Price', ylabel='Crime Rate'>

# %% [markdown]
# ##Correlations (Strong Positive Correlations)

# %% [markdown]
# Showing how Rent Price depends on other attributes

# %%
housing_numeric = housing.select_dtypes(include=['number'])
corr_matrix = housing_numeric.corr()
#print(corr_matrix)
corr_matrix['Rent Price'].sort_values(ascending=False)
# Out:
# Rent Price                     1.000000
# Area (sqft)                    0.951073
# Number of Rooms                0.949743
# Number of Bathrooms            0.711081
# Parking Spaces                 0.119258
# Avg People in Building         0.045940
# Crime Rate                    -0.036971
# Amenities Distance Avg (km)   -0.040739
# Age (years)                   -0.050916
# Lower Status Population       -0.065332
# Name: Rent Price, dtype: float64

# %% [markdown]
# ## Missing Attributes

# %% [markdown]
# - To take care of missing attributes you've three options :
# 1. Get rid of the missing datapoints (column)
# 2. Get rid of the whole attribute (row)
# 3. Set the value to some value(0,mean or median)

# %%
#1
#housing.dropna(subset=["Number of Rooms"])
#housing.shape

# %%
#2
#housing.drop("Number of Rooms", axis=1).shape

#Note:Original housing data remains unchanged

# %%
median = housing["Number of Rooms"].median()
median

#If any missing case fill it with median
housing["Number of Rooms"].fillna(median)
housing.shape
# Out:
# (5880, 12)

# %%
housing.describe()
# Out:
#        Number of Rooms  Number of Bathrooms  Area (sqft)  \
# count      5880.000000          5880.000000  5880.000000
# mean          2.126701             1.560374   437.121144
# std           1.171224             0.864582   282.364317
# min           1.000000             1.000000   100.007000
# 25%           1.000000             1.000000   200.399750
# 50%           2.000000             1.000000   359.116500
# 75%           3.000000             2.000000   614.708000
# max           4.000000             4.000000  1198.946000
#
#        Amenities Distance Avg (km)  Parking Spaces  Age (years)   Crime Rate  \
# count                  5880.000000     5880.000000  5880.000000  5880.000000
# mean                      7.529588        0.983503    12.656769     0.992765
# std                       4.298144        0.817960     7.185015     0.574108
# min                       0.109900        0.000000     0.000000     0.010000
# ...

# %% [markdown]
# We can also use imputer to fill the missing value
